# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
path=('/content/drive/MyDrive/univariate.csv')
df=pd.read_csv(path)
df.describe
plt.show()


import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/drive/MyDrive/univariate.csv')
df.plot(kind='scatter', x='45', y='160.5',marker='*')
plt.title('COUSTER INITIAL PLOT')
plt.grid()
plt.show()
